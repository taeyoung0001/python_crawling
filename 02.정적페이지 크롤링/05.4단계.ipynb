# %%
pip install pandas

# %%
pip install openpyxl

# %%
data= []
data.append(['카테고리1','상품명1' '링크1', '가격1'],)
data.append(['카테고리2','상품명2' '링크2', '가격2'],)
data.append(['카테고리10','상품명1' '링크1', '가격10'],)

data
# Out:
# [['카테고리1', '상품명1링크1', '가격1'],
#  ['카테고리2', '상품명2링크2', '가격2'],
#  ['카테고리10', '상품명1링크1', '가격10']]

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd 

data = []

for i in range(1, 5) :

    response = requests.get(f"https://startcoding.pythonanywhere.com/basic?keyword={i}")
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    items = soup.select('.product')
    for item in items :
        category = item.select_one('.product-category').text
        name = item.select_one('.product-name').text
        link = item.select_one('.product-name > a').attrs['href']
        price = item.select_one('.product-price').text.split('원')[0].replace(',' , '')
        print(category, name, link, price)
        data.append([category, name, link, price])

# %%
#데이터 프레임 만들기
df = pd.DataFrame(data, columns=['카테고리', '상품명' , '상세페이지링크' , '가격'])

df
# Out:
#     카테고리                                                상품명  \
# 0    노트북  에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i7, 512GB, 16GB...
# 1    노트북  삼성전자 노트북 플러스2 15.6, 퓨어 화이트, NT550XDA-K24AT, 펜티...
# 2    노트북  레노버 아이디어패드 슬림 1 15AMN7 15.6, 256GB, Free DOS, ...
# 3    노트북  레노버 V15 G4 AMN 15.6, Arctic Grey, 라이젠3, 256GB,...
# 4    노트북  LG 울트라PC 엣지 16, 차콜 그레이, 라이젠5, 256GB, 16GB, WIN...
# 5    노트북  베이직스 베이직북 14 3세대, BB1422SS, 256GB, White, WIN1...
# 6    노트북  레노버 아이디어패드 슬림 5i 14IRL 14, Cloud Grey, 코어i5, 5...
# 7    노트북  레노버 아이디어패드 슬림 5 16IRL 16, Cloud Grey, 512GB, 1...
# 8    노트북  에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i5, 512GB, 16GB...
# 9    노트북  삼성전자 갤럭시북 2 15.6, 500GB, 실버, NT550XED-K78AS, 코...
# 10   노트북  에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i7, 512GB, 16GB...
# 11   노트북  삼성전자 노트북 플러스2 15.6, 퓨어 화이트, NT550XDA-K24AT, 펜티...
# 12   노트북  레노버 아이디어패드 슬림 1 15AMN7 15.6, 256GB, Free DOS, ...
# 13   노트북  레노버 V15 G4 AMN 15.6, Arctic Grey, 라이젠3, 256GB,...
# 14   노트북  LG 울트라PC 엣지 16, 차콜 그레이, 라이젠5, 256GB, 16GB, WIN...
# 15   노트북  베이직스 베이직북 14 3세대, BB1422SS, 256GB, White, WIN1...
# 16   노트북  레노버 아이디어패드 슬림 5i 14IRL 14, Cloud Grey, 코어i5, 5...
# 17   노트북  레노버 아이디어패드 슬림 5 16IRL 16, Cloud Grey, 512GB, 1...
# 18   노트북  에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i5, 512GB, 16GB...
# 19   노트북  삼성전자 갤럭시북 2 15.6, 500GB, 실버, NT550XED-K78AS, 코...
# 20   노트북  레노버 아이디어패드 슬림 1 15AMN7 15.6, 256GB, Free DOS, ...
# 21   노트북  레노버 V15 G4 AMN 15.6, Arctic Grey, 라이젠3, 256GB,...
# 22   노트북  베이직스 베이직북 14 3세대, BB1422SS, 256GB, White, WIN1...
# 23  데스크탑  HP VICTUS 게이밍 데스크탑 TG02-1000KL (i5-13400F Free...
# 24  데스크탑  델 인스피론 3020 S 슬림 데스크탑 포그 블루 DN3020S-WH02KR (i5...
# 25  데스크탑  삼성전자 사무용 게임용 리퍼 중고컴퓨터 i3 i5 i7 GTX1060 무상A/S 1...
# 26  데스크탑  삼성전자 삼성 DM500SFZ-AD5A 최신 13세대 CPU-i5 데스크탑 슬림형 ...
# 27  데스크탑  HP S01-PF3000KL-WIN11 13세대\r\ni5-13400_(NVMe51...
# 28  데스크탑  삼성 컴퓨터 본체 조립PC 모니터포함 풀세트 사무용 게이밍 데스크탑 윈도우10, 본...
# 29   휴대폰                  삼성전자 갤럭시 A34 자급제, 어썸 그라파이트, 128GB
# 30   노트북  삼성전자 노트북 플러스2 15.6, 퓨어 화이트, NT550XDA-K24AT, 펜티...
# 31   노트북  레노버 V15 G4 AMN 15.6, Arctic Grey, 라이젠3, 256GB,...
# 32   노트북  베이직스 베이직북 14 3세대, BB1422SS, 256GB, White, WIN1...
# 33   노트북  레노버 아이디어패드 슬림 5i 14IRL 14, Cloud Grey, 코어i5, 5...
# 34  데스크탑  한성컴퓨터 데스크탑 화이트 TFG MX4A500 (라이젠5-5600G WIN미포함 ...
# 35  데스크탑  컴집 게이밍 조립식 컴퓨터 본체 배틀그라운드 디아블로4 롤 오버워치2 전문가용 건축...
# 36  데스크탑  HP VICTUS 게이밍 데스크탑 TG02-1000KL (i5-13400F Free...
# 37  데스크탑  델 인스피론 3020 S 슬림 데스크탑 포그 블루 DN3020S-WH02KR (i5...
# 38  데스크탑  HP S01-PF3000KL-WIN11 13세대\r\ni5-13400_(NVMe51...
# 39  데스크탑  삼성 컴퓨터 본체 조립PC 모니터포함 풀세트 사무용 게이밍 데스크탑 윈도우10, 본...
#
#                    상세페이지링크       가격
# 0    #product1_detail.html  1419000
# 1    #product2_detail.html   549000
# 2    #product3_detail.html   529000
# 3    #product4_detail.html   624000
# 4    #product5_detail.html  1135000
# 5    #product6_detail.html   398000
# 6    #product7_detail.html   899000
# 7    #product8_detail.html   929000
# 8    #product9_detail.html  1008000
# 9   #product10_detail.html  1149000
# 10   #product1_detail.html  1419000
# 11   #product2_detail.html   549000
# 12   #product3_detail.html   529000
# 13   #product4_detail.html   624000
# 14   #product5_detail.html  1135000
# 15   #product6_detail.html   398000
# 16   #product7_detail.html   899000
# 17   #product8_detail.html   929000
# 18   #product9_detail.html  1008000
# 19  #product10_detail.html  1149000
# 20   #product3_detail.html   529000
# 21   #product4_detail.html   624000
# 22   #product6_detail.html   398000
# 23  #product13_detail.html  1199000
# 24  #product14_detail.html   719000
# 25  #product16_detail.html   436000
# 26  #product17_detail.html   889000
# 27  #product18_detail.html   799000
# 28  #product19_detail.html  1099000
# 29  #product21_detail.html   408400
# 30   #product2_detail.html   549000
# 31   #product4_detail.html   624000
# 32   #product6_detail.html   398000
# 33   #product7_detail.html   899000
# 34  #product11_detail.html   499000
# 35  #product12_detail.html   699000
# 36  #product13_detail.html  1199000
# 37  #product14_detail.html   719000
# 38  #product18_detail.html   799000
# 39  #product19_detail.html  1099000

# %%
# 엑셀 저장
df.to_excel('result.xlsx', index=False)
